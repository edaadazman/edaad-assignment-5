# %%
import numpy as np
import pandas as pd

# %%
class KNN:
    def __init__(self, k=3, distance_metric='euclidean', batch_size=100):
        self.k = k
        self.distance_metric = distance_metric
        self.batch_size = batch_size

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        predictions = []
        num_test = X.shape[0]

        for i in range(0, num_test, self.batch_size):
            X_batch = X[i:i + self.batch_size]
            distances = self.compute_distance(X_batch)

            for dist in distances:
                k_indices = np.argsort(dist)[:self.k]  # Get indices of the k nearest neighbors
                k_nearest_labels = self.y_train[k_indices].astype(int)  # Get the labels of the k nearest neighbors
                
                # Instead of majority vote, calculate the proportion of 1s (probability of churn)
                churn_prob = np.mean(k_nearest_labels)  # Proportion of 1s
                predictions.append(churn_prob)

        # Ensure predictions are floats between 0 and 1
        return np.array(predictions, dtype=float)



    def compute_distance(self, X_test):
        # Efficient vectorized Euclidean distance calculation
        X_train_squared = np.sum(np.square(self.X_train), axis=1)
        X_test_squared = np.sum(np.square(X_test), axis=1).reshape(-1, 1)
        distances = np.sqrt(X_train_squared + X_test_squared - 2 * np.dot(X_test, self.X_train.T))
        return distances

# %%
def preprocess_data(train_path, test_path):
    print("Loading and preprocessing data...")
    train_data = pd.read_csv(train_path)
    test_data = pd.read_csv(test_path)

    train_data = train_data.drop(['CustomerId', 'Surname'], axis=1)
    test_data = test_data.drop(['CustomerId', 'Surname'], axis=1)

    train_data['Geography'] = train_data['Geography'].astype('category').cat.codes
    train_data['Gender'] = train_data['Gender'].astype('category').cat.codes
    test_data['Geography'] = test_data['Geography'].astype('category').cat.codes
    test_data['Gender'] = test_data['Gender'].astype('category').cat.codes

    X_train = train_data.drop('Exited', axis=1).values
    y_train = train_data['Exited'].values
    X_test = test_data.values

    mean = np.mean(X_train, axis=0)
    std = np.std(X_train, axis=0)

    # Standardize the training and test data
    X_train = (X_train - mean) / std
    X_test = (X_test - mean) / std

    print("Data preprocessing completed.")
    return X_train, y_train, X_test

# %%
def cross_validate(X, y, knn, n_splits=5):
    print("Starting cross-validation...")
    n = len(X)
    fold_size = n // n_splits
    indices = np.arange(n)
    np.random.shuffle(indices)

    accuracy_scores = []

    for fold in range(n_splits):
        print(f"Processing fold {fold + 1} of {n_splits}...")
        val_start = fold * fold_size
        val_end = val_start + fold_size if fold != n_splits - 1 else n
        val_indices = indices[val_start:val_end]
        train_indices = np.concatenate([indices[:val_start], indices[val_end:]])

        X_train, y_train = X[train_indices], y[train_indices]
        X_val, y_val = X[val_indices], y[val_indices]

        knn.fit(X_train, y_train)
        y_pred = knn.predict(X_val)

        accuracy = np.mean(y_pred == y_val)
        accuracy_scores.append(accuracy)

        print(f"Fold {fold + 1} accuracy: {accuracy:.4f}")

    print("Cross-validation completed.")
    return np.mean(accuracy_scores)

# %%
X, y, X_test = preprocess_data('./train.csv', './test.csv')

knn = KNN(k=5, distance_metric='euclidean')

cv_scores = cross_validate(X, y, knn)
print("Cross-validation scores:", cv_scores)

best_k = 5
best_score = 0
for k in range(1, 20):
    print(f"Evaluating k={k}...")
    knn = KNN(k=k, distance_metric='euclidean')
    cv_score = cross_validate(X, y, knn)
    print(f"k = {k}, Cross-validation accuracy = {cv_score:.4f}")

    if cv_score > best_score:
        best_score = cv_score
        best_k = k

print(f"Best k found: {best_k} with cross-validation accuracy: {best_score:.4f}")

print(f"Training final model with k={best_k} on full dataset...")
knn = KNN(k=best_k, distance_metric='euclidean')
knn.fit(X, y)
test_predictions = knn.predict(X_test)

pd.DataFrame({'id': pd.read_csv('./test.csv')['id'], 'Exited': test_predictions}).to_csv('submissions.csv', index=False)
print("Predictions saved successfully.")
# Out:
# Loading and preprocessing data...
# Data preprocessing completed.
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.6187
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.5907
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.6073
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.6167
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.6223
# Cross-validation completed.
# Cross-validation scores: 0.6111333333333333
# Evaluating k=1...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.8440
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.8460
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.8377
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.8417
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.8480
# Cross-validation completed.
# k = 1, Cross-validation accuracy = 0.8435
# Evaluating k=2...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.7613
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.7697
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.7540
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.7510
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.7513
# Cross-validation completed.
# k = 2, Cross-validation accuracy = 0.7575
# Evaluating k=3...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.6967
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.6990
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.7073
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.6910
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.6957
# Cross-validation completed.
# k = 3, Cross-validation accuracy = 0.6979
# Evaluating k=4...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.6403
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.6483
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.6573
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.6613
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.6403
# Cross-validation completed.
# k = 4, Cross-validation accuracy = 0.6495
# Evaluating k=5...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.6127
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.6053
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.6023
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.6097
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.6260
# Cross-validation completed.
# k = 5, Cross-validation accuracy = 0.6112
# Evaluating k=6...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.5773
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.5890
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.5907
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.5723
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.5840
# Cross-validation completed.
# k = 6, Cross-validation accuracy = 0.5827
# Evaluating k=7...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.5737
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.5403
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.5540
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.5653
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.5580
# Cross-validation completed.
# k = 7, Cross-validation accuracy = 0.5583
# Evaluating k=8...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.5250
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.5243
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.5387
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.5307
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.5360
# Cross-validation completed.
# k = 8, Cross-validation accuracy = 0.5309
# Evaluating k=9...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.5113
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.5233
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.4983
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.5213
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.5157
# Cross-validation completed.
# k = 9, Cross-validation accuracy = 0.5140
# Evaluating k=10...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.5123
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.4840
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.4977
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.4960
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.4907
# Cross-validation completed.
# k = 10, Cross-validation accuracy = 0.4961
# Evaluating k=11...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.4740
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.4927
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.4783
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.4597
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.4837
# Cross-validation completed.
# k = 11, Cross-validation accuracy = 0.4777
# Evaluating k=12...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.4557
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.4633
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.4670
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.4587
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.4623
# Cross-validation completed.
# k = 12, Cross-validation accuracy = 0.4614
# Evaluating k=13...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.4583
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.4417
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.4420
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.4460
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.4507
# Cross-validation completed.
# k = 13, Cross-validation accuracy = 0.4477
# Evaluating k=14...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.4367
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.4513
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.4313
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.4267
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.4297
# Cross-validation completed.
# k = 14, Cross-validation accuracy = 0.4351
# Evaluating k=15...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.4243
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.4077
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.4197
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.4267
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.4117
# Cross-validation completed.
# k = 15, Cross-validation accuracy = 0.4180
# Evaluating k=16...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.4183
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.4057
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.4103
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.3967
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.4390
# Cross-validation completed.
# k = 16, Cross-validation accuracy = 0.4140
# Evaluating k=17...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.3950
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.4000
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.4080
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.3867
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.3997
# Cross-validation completed.
# k = 17, Cross-validation accuracy = 0.3979
# Evaluating k=18...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.3790
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.3960
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.3900
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.3920
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.3777
# Cross-validation completed.
# k = 18, Cross-validation accuracy = 0.3869
# Evaluating k=19...
# Starting cross-validation...
# Processing fold 1 of 5...
# Fold 1 accuracy: 0.3757
# Processing fold 2 of 5...
# Fold 2 accuracy: 0.3877
# Processing fold 3 of 5...
# Fold 3 accuracy: 0.3830
# Processing fold 4 of 5...
# Fold 4 accuracy: 0.3670
# Processing fold 5 of 5...
# Fold 5 accuracy: 0.3657
# Cross-validation completed.
# k = 19, Cross-validation accuracy = 0.3758
# Best k found: 1 with cross-validation accuracy: 0.8435
# Training final model with k=1 on full dataset...
# Predictions saved successfully.
